# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Diamonds.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.isnull()
# Out:
#        Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0           False  False  False  False    False  False  False  False  False
# 1           False  False  False  False    False  False  False  False  False
# 2           False  False  False  False    False  False  False  False  False
# 3           False  False  False  False    False  False  False  False  False
# 4           False  False  False  False    False  False  False  False  False
# ...           ...    ...    ...    ...      ...    ...    ...    ...    ...
# 53935       False  False  False  False    False  False  False  False  False
# 53936       False  False  False  False    False  False  False  False  False
# 53937       False  False  False  False    False  False  False  False  False
# 53938       False  False  False  False    False  False  False  False  False
# 53939       False  False  False  False    False  False  False  False  False
#
#            y      z
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 53935  False  False
# 53936  False  False
# 53937  False  False
# 53938  False  False
# 53939  False  False
#
# [53940 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df["carat"].value_counts()
# Out:
# carat
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: count, Length: 273, dtype: int64

# %%
df["Unnamed: 0"].value_counts()
# Out:
# Unnamed: 0
# 1        1
# 35978    1
# 35954    1
# 35955    1
# 35956    1
#         ..
# 17984    1
# 17985    1
# 17986    1
# 17987    1
# 53940    1
# Name: count, Length: 53940, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
df["depth"].value_counts()
# Out:
# depth
# 62.0    2239
# 61.9    2163
# 61.8    2077
# 62.2    2039
# 62.1    2020
#         ...
# 71.3       1
# 44.0       1
# 53.0       1
# 53.1       1
# 54.7       1
# Name: count, Length: 184, dtype: int64

# %%
df["price"].value_counts()
# Out:
# price
# 605      132
# 802      127
# 625      126
# 828      125
# 776      124
#         ...
# 8816       1
# 14704      1
# 14699      1
# 14698      1
# 9793       1
# Name: count, Length: 11602, dtype: int64

# %%
df["table"].value_counts()
# Out:
# table
# 56.0    9881
# 57.0    9724
# 58.0    8369
# 59.0    6572
# 55.0    6268
#         ...
# 51.6       1
# 63.5       1
# 43.0       1
# 62.4       1
# 61.6       1
# Name: count, Length: 127, dtype: int64

# %%
df["x"].value_counts()
# Out:
# x
# 4.37     448
# 4.34     437
# 4.33     429
# 4.38     428
# 4.32     425
#         ...
# 10.74      1
# 9.36       1
# 8.89       1
# 10.23      1
# 10.00      1
# Name: count, Length: 554, dtype: int64

# %%
df["y"].value_counts()
# Out:
# y
# 4.34     437
# 4.37     435
# 4.35     425
# 4.33     421
# 4.32     414
#         ...
# 8.89       1
# 10.16      1
# 9.46       1
# 9.63       1
# 31.80      1
# Name: count, Length: 552, dtype: int64

# %%
df["z"].value_counts()
# Out:
# z
# 2.70     767
# 2.69     748
# 2.71     738
# 2.68     730
# 2.72     697
#         ...
# 5.79       1
# 5.72       1
# 5.91       1
# 5.61       1
# 31.80      1
# Name: count, Length: 375, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Unnamed: 0    53940
# carat           273
# cut               5
# color             7
# clarity           8
# depth           184
# table           127
# price         11602
# x               554
# y               552
# z               375
# dtype: int64

# %%
df.head(50)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1            2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2            3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3            4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4            5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5            6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6            7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7            8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8            9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9           10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 11          12   0.23      Ideal     J     VS1   62.8   56.0    340  3.93
# 12          13   0.22    Premium     F     SI1   60.4   61.0    342  3.88
# 13          14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 14          15   0.20    Premium     E     SI2   60.2   62.0    345  3.79
# 15          16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 16          17   0.30      Ideal     I     SI2   62.0   54.0    348  4.31
# 17          18   0.30       Good     J     SI1   63.4   54.0    351  4.23
# 18          19   0.30       Good     J     SI1   63.8   56.0    351  4.23
# 19          20   0.30  Very Good     J     SI1   62.7   59.0    351  4.21
# 20          21   0.30       Good     I     SI2   63.3   56.0    351  4.26
# 21          22   0.23  Very Good     E     VS2   63.8   55.0    352  3.85
# 22          23   0.23  Very Good     H     VS1   61.0   57.0    353  3.94
# 23          24   0.31  Very Good     J     SI1   59.4   62.0    353  4.39
# 24          25   0.31  Very Good     J     SI1   58.1   62.0    353  4.44
# 25          26   0.23  Very Good     G    VVS2   60.4   58.0    354  3.97
# 26          27   0.24    Premium     I     VS1   62.5   57.0    355  3.97
# 27          28   0.30  Very Good     J     VS2   62.2   57.0    357  4.28
# 28          29   0.23  Very Good     D     VS2   60.5   61.0    357  3.96
# 29          30   0.23  Very Good     F     VS1   60.9   57.0    357  3.96
# 30          31   0.23  Very Good     F     VS1   60.0   57.0    402  4.00
# 31          32   0.23  Very Good     F     VS1   59.8   57.0    402  4.04
# 32          33   0.23  Very Good     E     VS1   60.7   59.0    402  3.97
# 33          34   0.23  Very Good     E     VS1   59.5   58.0    402  4.01
# 34          35   0.23  Very Good     D     VS1   61.9   58.0    402  3.92
# 35          36   0.23       Good     F     VS1   58.2   59.0    402  4.06
# 36          37   0.23       Good     E     VS1   64.1   59.0    402  3.83
# 37          38   0.31       Good     H     SI1   64.0   54.0    402  4.29
# 38          39   0.26  Very Good     D     VS2   60.8   59.0    403  4.13
# 39          40   0.33      Ideal     I     SI2   61.8   55.0    403  4.49
# 40          41   0.33      Ideal     I     SI2   61.2   56.0    403  4.49
# 41          42   0.33      Ideal     J     SI1   61.1   56.0    403  4.49
# 42          43   0.26       Good     D     VS2   65.2   56.0    403  3.99
# 43          44   0.26       Good     D     VS1   58.4   63.0    403  4.19
# 44          45   0.32       Good     H     SI2   63.1   56.0    403  4.34
# 45          46   0.29    Premium     F     SI1   62.4   58.0    403  4.24
# 46          47   0.32  Very Good     H     SI2   61.8   55.0    403  4.35
# 47          48   0.32       Good     H     SI2   63.8   56.0    403  4.36
# 48          49   0.25  Very Good     E     VS2   63.3   60.0    404  4.00
# 49          50   0.29  Very Good     H     SI2   60.7   60.0    404  4.33
#
#        y     z
# 0   3.98  2.43
# 1   3.84  2.31
# 2   4.07  2.31
# 3   4.23  2.63
# 4   4.35  2.75
# 5   3.96  2.48
# 6   3.98  2.47
# 7   4.11  2.53
# 8   3.78  2.49
# 9   4.05  2.39
# 10  4.28  2.73
# 11  3.90  2.46
# 12  3.84  2.33
# 13  4.37  2.71
# 14  3.75  2.27
# 15  4.42  2.68
# 16  4.34  2.68
# 17  4.29  2.70
# 18  4.26  2.71
# 19  4.27  2.66
# 20  4.30  2.71
# 21  3.92  2.48
# 22  3.96  2.41
# 23  4.43  2.62
# 24  4.47  2.59
# 25  4.01  2.41
# 26  3.94  2.47
# 27  4.30  2.67
# 28  3.97  2.40
# 29  3.99  2.42
# 30  4.03  2.41
# 31  4.06  2.42
# 32  4.01  2.42
# 33  4.06  2.40
# 34  3.96  2.44
# 35  4.08  2.37
# 36  3.85  2.46
# 37  4.31  2.75
# 38  4.16  2.52
# 39  4.51  2.78
# 40  4.50  2.75
# 41  4.55  2.76
# 42  4.02  2.61
# 43  4.24  2.46
# 44  4.37  2.75
# 45  4.26  2.65
# 46  4.42  2.71
# 47  4.38  2.79
# 48  4.03  2.54
# 49  4.37  2.64

# %%
df["Unnamed: 0"].unique()
# Out:
# array([    1,     2,     3, ..., 53938, 53939, 53940], dtype=int64)

# %%
df.drop(columns = "Unnamed: 0",inplace=True)

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
def outliers(x):
    y=x.select_dtypes(include=[int,float])
    for i in y:
        sns.boxplot(x=df[i])
        plt.title(i)
        plt.show()

# %%
outliers(df)

# %%
def IQR(x):
    q1 = x.quantile(0.25)
    q3 = x.quantile(0.75)
    iqr = q3 - q1
    LF = q1 - (1.5*iqr)
    UF = q3 + (1.5*iqr)
    print("LF-->",LF)
    print("UF-->",UF)

# %%
IQR(df["carat"])
# Out:
# LF--> -0.5599999999999999
# UF--> 2.0

# %%
IQR(df["depth"])
# Out:
# LF--> 58.75
# UF--> 64.75

# %%
IQR(df["price"])
# Out:
# LF--> -5612.625
# UF--> 11890.375

# %%
IQR(df["table"])
# Out:
# LF--> 51.5
# UF--> 63.5

# %%
IQR(df["x"])
# Out:
# LF--> 1.9649999999999999
# UF--> 9.285

# %%
IQR(df["y"])
# Out:
# LF--> 1.9899999999999993
# UF--> 9.27

# %%
IQR(df["z"])
# Out:
# LF--> 1.23
# UF--> 5.710000000000001

# %%
df["carat"] = np.where(df["carat"]>2.0,2.0,df["carat"])
df["carat"] = np.where(df["carat"]<-0.5599999999999999,-0.5599999999999999,df["carat"])
df["depth"] = np.where(df["depth"]>64.75,64.75,df["depth"])
df["depth"] = np.where(df["depth"]<58.75,58.75,df["depth"])
df["price"] = np.where(df["price"]>11890.375,11890.375,df["price"])
df["price"] = np.where(df["price"]<-5612.625,-5612.625,df["price"])
df["table"] = np.where(df["table"]>63.5,63.5,df["table"])
df["table"] = np.where(df["table"]<51.5,51.5,df["table"])
df["x"] = np.where(df["x"]>9.285,9.285,df["x"])
df["x"] = np.where(df["x"]<1.9649999999999999,1.9649999999999999,df["x"])
df["y"] = np.where(df["y"]>9.27,9.27,df["y"])
df["y"] = np.where(df["y"]<1.9899999999999993,1.9899999999999993,df["y"])
df["z"] = np.where(df["z"]>1.23,1.23,df["z"])
df["z"] = np.where(df["z"]<5.710000000000001,5.710000000000001,df["z"])

# %%
import seaborn as sns
def outliers(x):
    y=x.select_dtypes(include=[int,float])
    for i in y:
        sns.boxplot(x=df[i])
        plt.title(i)
        plt.show()

# %%
outliers(df)

# %%
num = df.select_dtypes(include=[int,float])

# %%
num
# Out:
#        carat  depth  table   price     x     y     z
# 0       0.23  61.50   55.0   326.0  3.95  3.98  5.71
# 1       0.21  59.80   61.0   326.0  3.89  3.84  5.71
# 2       0.23  58.75   63.5   327.0  4.05  4.07  5.71
# 3       0.29  62.40   58.0   334.0  4.20  4.23  5.71
# 4       0.31  63.30   58.0   335.0  4.34  4.35  5.71
# ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72  60.80   57.0  2757.0  5.75  5.76  5.71
# 53936   0.72  63.10   55.0  2757.0  5.69  5.75  5.71
# 53937   0.70  62.80   60.0  2757.0  5.66  5.68  5.71
# 53938   0.86  61.00   58.0  2757.0  6.15  6.12  5.71
# 53939   0.75  62.20   55.0  2757.0  5.83  5.87  5.71
#
# [53794 rows x 7 columns]

# %%
num.corr()
# Out:
#           carat     depth     table     price         x         y   z
# carat  1.000000  0.021519  0.186775  0.936545  0.981959  0.981231 NaN
# depth  0.021519  1.000000 -0.299939 -0.009098 -0.029115 -0.031816 NaN
# table  0.186775 -0.299939  1.000000  0.136167  0.197725  0.191757 NaN
# price  0.936545 -0.009098  0.136167  1.000000  0.911937  0.913459 NaN
# x      0.981959 -0.029115  0.197725  0.911937  1.000000  0.998357 NaN
# y      0.981231 -0.031816  0.191757  0.913459  0.998357  1.000000 NaN
# z           NaN       NaN       NaN       NaN       NaN       NaN NaN

# %%
plt.figure(figsize=(10,6))
sns.heatmap(num.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
df.select_dtypes(object)
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53794 rows x 3 columns]

# %%
df.select_dtypes(object).columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13032
# VS2     12229
# SI2      9150
# VS1      8156
# VVS2     5056
# VVS1     3647
# IF       1784
# I1        740
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11262
# E     9776
# F     9520
# H     8272
# D     6755
# I     5407
# J     2802
# Name: count, dtype: int64

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21488
# Premium      13748
# Very Good    12069
# Good          4891
# Fair          1598
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns = ['clarity', 'color', 'cut'])

# %%
df.columns
# Out:
# Index(['carat', 'depth', 'table', 'price', 'x', 'y', 'z', 'clarity_I1',
#        'clarity_IF', 'clarity_SI1', 'clarity_SI2', 'clarity_VS1',
#        'clarity_VS2', 'clarity_VVS1', 'clarity_VVS2', 'color_D', 'color_E',
#        'color_F', 'color_G', 'color_H', 'color_I', 'color_J', 'cut_Fair',
#        'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good'],
#       dtype='object')

# %%
X = df[['carat', 'depth', 'table', 'x', 'y', 'z', 'clarity_I1',
       'clarity_IF', 'clarity_SI1', 'clarity_SI2', 'clarity_VS1',
       'clarity_VS2', 'clarity_VVS1', 'clarity_VVS2', 'color_D', 'color_E',
       'color_F', 'color_G', 'color_H', 'color_I', 'color_J', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good']]
Y = df['price']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   carat          53794 non-null  float64
#  1   depth          53794 non-null  float64
#  2   table          53794 non-null  float64
#  3   x              53794 non-null  float64
#  4   y              53794 non-null  float64
#  5   z              53794 non-null  float64
#  6   clarity_I1     53794 non-null  bool
#  7   clarity_IF     53794 non-null  bool
#  8   clarity_SI1    53794 non-null  bool
#  9   clarity_SI2    53794 non-null  bool
#  10  clarity_VS1    53794 non-null  bool
#  11  clarity_VS2    53794 non-null  bool
#  12  clarity_VVS1   53794 non-null  bool
#  13  clarity_VVS2   53794 non-null  bool
#  14  color_D        53794 non-null  bool
#  15  color_E        53794 non-null  bool
#  16  color_F        53794 non-null  bool
#  17  color_G        53794 non-null  bool
#  18  color_H        53794 non-null  bool
#  19  color_I        53794 non-null  bool
#  20  color_J        53794 non-null  bool
#  21  cut_Fair       53794 non-null  bool
#  22  cut_Good       53794 non-null  bool
#  23  cut_Ideal      53794 non-null  bool
#  24  cut_Premium    53794 non-null  bool
#  25  cut_Very Good  53794 non-null  bool
# dtypes: bool(20), float64(6)
# memory usage: 3.9 MB

# %%
sns.displot(np.square(df["price"]))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = .2, random_state = 77)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,Y_train)
# Out:
# 0.9406183768899367

# %%
print("R_square",lr.score(X_train,Y_train))
# Out:
# R_square 0.9406183768899367

# %%
X = df[['carat', 'depth', 'table', 'x', 'y', 'z', 'clarity_I1',
       'clarity_IF', 'clarity_SI1', 'clarity_SI2', 'clarity_VS1',
       'clarity_VS2', 'clarity_VVS1', 'clarity_VVS2', 'color_D', 'color_E',
       'color_F', 'color_G', 'color_H', 'color_I', 'color_J', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good']]
Y = np.log1p(df['price'])

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = .2, random_state = 77)

# %%
l1 = LinearRegression()

# %%
l1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
l1.score(X_train,Y_train)
# Out:
# 0.9675486186711065

# %%
print("R_square",l1.score(X_train,Y_train))
# Out:
# R_square 0.9675486186711065

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
df["price"]
# Out:
# 0         326.0
# 1         326.0
# 2         327.0
# 3         334.0
# 4         335.0
#           ...
# 53935    2757.0
# 53936    2757.0
# 53937    2757.0
# 53938    2757.0
# 53939    2757.0
# Name: price, Length: 53794, dtype: float64

# %%
actual = np.exp(Y_train)
pred = np.exp(l1.predict(X_train))
error = actual - pred
MSE = np.mean(np.square(error))
RMSE = np.sqrt(MSE)

# %%
print("MSE",MSE)
print("RMSE",RMSE)
# Out:
# MSE 2513977.03391928
# RMSE 1585.5525957593711

# %%
from sklearn.metrics import root_mean_squared_error

# %%
print("mean_sq_er",mean_squared_error(actual,pred))
print("RMSE",root_mean_squared_error(actual,pred))
# Out:
# mean_sq_er 2513977.03391928
# RMSE 1585.5525957593711
